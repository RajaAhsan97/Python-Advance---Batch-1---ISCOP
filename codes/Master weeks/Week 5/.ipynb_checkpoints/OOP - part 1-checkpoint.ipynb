# %% [markdown]
# # Programming Paradigm
#
# Programming krny ka style:
#
# 1. Sequential Programming         ---> line by line             ---> jb koi code likhta hun , agr koi code mjhy 2bara use krna h to wo code mjhy 2bara likhna hoga
# 2. Procedural Programming         ---> functional bnaty hein    ---> wo code m ny function m daal dia, jb wo code mjhy use krna hoga to m function call karunga     ----> DEBUG krna asaan hogya
# 3. Object oriented programming    ---> Objects                  --->

# %% [markdown]
# OPPS mein objects k throght kaam krwaty h
#
# Opps mein hum real world scenarios ko asaani sy likh sakty hein

# %% [markdown]
# ## What is an object?
#     Anything under observation is an object for e.g. human, animal etc
#
#     Object must have:
#     - Characteristics or properties
#     - Behaviour or Actions

# %% [markdown]
# #### Jb hum pehli bar Object bnaty hein to uska design krty hein --> Design krny ko hum OBJECT ki CLASS kehty hein

# %% [markdown]
# ### What is Class?
#         Design of Object (Object kesa hoga)
#
#         - Class is a blueprint / template of an Object

# %% [markdown]
# ## Classes and Object:

# %%
# computer ka object sooch raha hun

class Computer:
    pass

# %%
# object Designing

class Computer:
    # characteristics / properties / attributes / variables
    ram = "8 GB"
    processor = "Core i9" 
    storage = "1TB"
    price = 100000
    model = "DELL"

    # behaviours
    def coding(self):
        print("Coding...")

    def designing(self):
        print("Designing...")

    def browsing(self):
        print("Browsing...")

# %% [markdown]
# ### Ab mjhy Object create krna h

# %%
# Object is an instance of class
# it will be a copy of class
# it will follow its class

# %%
comp1 = Computer()
comp2 = Computer()
comp3 = Computer()

# %%
# meri class ki tamam functionality and attributes 3no computer m agaey

# %%
comp1.price
# Out:
# 100000

# %%
comp2.price
# Out:
# 100000

# %%
comp3.price
# Out:
# 100000

# %%
comp1.coding()
# Out:
# Coding...

# %%
comp1.browsing()
# Out:
# Browsing...

# %%
comp1.designing()
# Out:
# Designing...

# %%
comp1.price = 60000

# %%
comp1.price
# Out:
# 60000

# %% [markdown]
# ### Constructor / Initializer:
#     object ky variables m values initialize krwata h

# %% [markdown]
# ### if we do not define any constructor, then default constructor is initialize, which can take and give no values

# %%
# object Designing

class Computer:

    # constructor
    def __init__(self, ram, processor, storage, price, model):
        # characteristics / properties / attributes / variables
        self.ram = ram
        self.processor = processor 
        self.storage = storage
        self.price = price
        self.model = model

    # behaviours
    # METHODS
    def coding(self):
        print(f"I am Coding on {self.model}...")

    def designing(self):
        print(f"I am Designing {self.model}...")

    def browsing(self):
        print(f"I am Browsing on {self.model}...")

# %%
comp1 = Computer()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 comp1 = Computer()
#
# TypeError: Computer.__init__() missing 5 required positional arguments: 'ram', 'processor', 'storage', 'price', and 'model'

# %%
comp1 = Computer("8GB", "corei7", "1TB", "50000", "DELL")

# %%
comp2 = Computer("16GB", "corei9", "2TB", "90000", "HP")

# %%
comp1

# %%
comp1.coding()
# Out:
# I am Coding on DELL...

# %%
comp2.coding()
# Out:
# I am Coding on HP...

# %%
Computer.browsing(comp1)
# Out:
# I am Browsing on DELL...

# %%
comp1.browsing()
# Out:
# I am Browsing on DELL...

# %% [markdown]
# ## Methods:
#     functions defined inside class is called methods
#
#     Two types of methods:
#         1. class methods:
#                 if no self in methods
#         2. Instance methods:
#                 if self in methods

# %%
class Students:
    # constructors
    def __init__(self, roll, name, course, gender, email):
        # attributes
        self.roll = roll
        self.name = name
        self.course = course
        self.gender = gender
        self.email = email

    # Instance methods
    def attend_class(self):
        print(f"{self.name} is attending class")

    def appear_exam(self):
        print(f"{self.name} {self.roll} is appearing in exam")

    def result(self):
        print(f"{self.name} is Pass in exam")

# %%
s1 = Students("AP01", "Ahsan", "Python Advance", "Male", "xyz@gmail.com")

# %%
s1

# %%
s2 = Students("AP02", "Ehsan", "Python Advance", "Male", "XYZ@gmail.com")

# %%
s1.attend_class()
# Out:
# Ahsan is attending class

# %%
s2.attend_class()
# Out:
# Ehsan is attending class

# %%
s1.name = "saad"

# %%
s1.attend_class()
# Out:
# saad is attending class

# %% [markdown]
# ## Pillars of OOPs
#         1. Encapsulation
#         2. Inheritance
#         3. Polymorphism
#         4. Abstraction
